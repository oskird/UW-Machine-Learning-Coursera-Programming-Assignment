# %% [markdown]
# # Regression Week 4: Ridge Regression (gradient descent)

# %% [markdown]
# In this notebook, you will implement ridge regression via gradient descent. You will:
# * Convert an SFrame into a Numpy array
# * Write a Numpy function to compute the derivative of the regression weights with respect to a single feature
# * Write gradient descent function to compute the regression weights given an initial weight vector, step size, tolerance, and L2 penalty

# %% [markdown]
# # Fire up graphlab create

# %% [markdown]
# Make sure you have the latest version of GraphLab Create (>= 1.7)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
sales = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# If we want to do any "feature engineering" like creating new features or adjusting existing ones we should do this directly using the SFrames as seen in the first notebook of Week 2. For this notebook, however, we will work with the existing features.

# %% [markdown]
# # Import useful functions from previous notebook

# %% [markdown]
# As in Week 2, we convert the SFrame into a 2D Numpy array. Copy and paste `get_numpy_data()` from the second notebook of Week 2.

# %%
def get_numpy_data(data, features, output):
    data['constant'] = 1 # this is how you add a constant column to an SFrame
    # add the column 'constant' to the front of the features list so that we can extract it along with the others:
    features = ['constant'] + features # this is how you combine two lists
    # select the columns of data_SFrame given by the features list into the SFrame features_sframe (now including constant):

    # the following line will convert the features_SFrame into a numpy matrix:
    feature_matrix = np.array(data.loc[:,features])
    # assign the column of data_sframe associated with the output to the SArray output_sarray

    # the following will convert the SArray into a numpy array by first converting it to a list
    output_array = np.array(data[output])
    return(feature_matrix, output_array)

# %% [markdown]
# Also, copy and paste the `predict_output()` function to compute the predictions for an entire matrix of features given the matrix and the weights:

# %%
def predict_output(feature_matrix, weights):
    # assume feature_matrix is a numpy matrix containing the features as columns and weights is a corresponding numpy array
    # create the predictions vector by using np.dot()
    predictions = np.dot(feature_matrix, weights)
    return(predictions)

# %% [markdown]
# # Computing the Derivative

# %% [markdown]
# We are now going to move to computing the derivative of the regression cost function. Recall that the cost function is the sum over the data points of the squared difference between an observed output and a predicted output, plus the L2 penalty term.
# ```
# Cost(w)
# = SUM[ (prediction - output)^2 ]
# + l2_penalty*(w[0]^2 + w[1]^2 + ... + w[k]^2).
# ```
#
# Since the derivative of a sum is the sum of the derivatives, we can take the derivative of the first part (the RSS) as we did in the notebook for the unregularized case in Week 2 and add the derivative of the regularization part.  As we saw, the derivative of the RSS with respect to `w[i]` can be written as:
# ```
# 2*SUM[ error*[feature_i] ].
# ```
# The derivative of the regularization term with respect to `w[i]` is:
# ```
# 2*l2_penalty*w[i].
# ```
# Summing both, we get
# ```
# 2*SUM[ error*[feature_i] ] + 2*l2_penalty*w[i].
# ```
# That is, the derivative for the weight for feature i is the sum (over data points) of 2 times the product of the error and the feature itself, plus `2*l2_penalty*w[i]`.
#
# **We will not regularize the constant.**  Thus, in the case of the constant, the derivative is just twice the sum of the errors (without the `2*l2_penalty*w[0]` term).
#
# Recall that twice the sum of the product of two vectors is just twice the dot product of the two vectors. Therefore the derivative for the weight for feature_i is just two times the dot product between the values of feature_i and the current errors, plus `2*l2_penalty*w[i]`.
#
# With this in mind complete the following derivative function which computes the derivative of the weight given the value of the feature (over all data points) and the errors (over all data points).  To decide when to we are dealing with the constant (so we don't regularize it) we added the extra parameter to the call `feature_is_constant` which you should set to `True` when computing the derivative of the constant and `False` otherwise.

# %%
def feature_derivative_ridge(errors, feature, weight, l2_penalty, feature_is_constant):
    # If feature_is_constant is True, derivative is twice the dot product of errors and feature
    if feature_is_constant== True:
        derivative = 2*np.sum(errors*feature)
    # Otherwise, derivative is twice the dot product plus 2*l2_penalty*weight
    else:
        derivative = 2*np.sum(errors*feature) + 2*l2_penalty*weight
    return derivative

# %% [markdown]
# To test your feature derivartive run the following:

# %%
(example_features, example_output) = get_numpy_data(sales, ['sqft_living'], 'price') 
my_weights = np.array([1., 10.])
test_predictions = predict_output(example_features, my_weights) 
errors = test_predictions - example_output # prediction errors

# next two lines should print the same values
print(feature_derivative_ridge(errors, example_features[:,1], my_weights[1], 1, False))
print(np.sum(errors*example_features[:,1])*2+20.)
print('')

# next two lines should print the same values
print(feature_derivative_ridge(errors, example_features[:,0], my_weights[0], 1, True))
print(np.sum(errors)*2.)
# Out:
# -56554166815950.0
# -56554166815950.0
#
# -22446749330.0
# -22446749330.0

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# Now we will write a function that performs a gradient descent. The basic premise is simple. Given a starting point we update the current weights by moving in the negative gradient direction. Recall that the gradient is the direction of *increase* and therefore the negative gradient is the direction of *decrease* and we're trying to *minimize* a cost function.
#
# The amount by which we move in the negative gradient *direction*  is called the 'step size'. We stop when we are 'sufficiently close' to the optimum. Unlike in Week 2, this time we will set a **maximum number of iterations** and take gradient steps until we reach this maximum number. If no maximum number is supplied, the maximum should be set 100 by default. (Use default parameter values in Python.)
#
# With this in mind, complete the following gradient descent function below using your derivative function above. For each step in the gradient descent, we update the weight for each feature before computing our stopping criteria.

# %%
def ridge_regression_gradient_descent(feature_matrix, output, initial_weights, step_size, l2_penalty, print=True, max_iterations=100):
    if print==True:
        print('Starting gradient descent with l2_penalty = ' + str(l2_penalty))
    
    weights = np.array(initial_weights) # make sure it's a numpy array
    iteration = 0 # iteration counter
    print_frequency = 1  # for adjusting frequency of debugging output
    
    #while not reached maximum number of iterations:
    while iteration<max_iterations:
        iteration += 1  # increment iteration counter
        ### === code section for adjusting frequency of debugging output. ===
        if iteration == 10:
            print_frequency = 10
        if iteration == 100:
            print_frequency = 100
        if iteration%print_frequency==0:
            if print==True:
                print('Iteration = ' + str(iteration))
        ### === end code section ===
        
        # compute the predictions based on feature_matrix and weights using your predict_output() function
        predictions = predict_output(feature_matrix, weights)
        # compute the errors as predictions - output
        errors = predictions - output
        # from time to time, print the value of the cost function
        if iteration%print_frequency==0:
            if print==True:
                print('Cost function = ', str(np.dot(errors,errors) + l2_penalty*(np.dot(weights,weights) - weights[0]**2)))
        
        for i in range(len(weights)): # loop over each weight
            # Recall that feature_matrix[:,i] is the feature column associated with weights[i]
            # compute the derivative for weight[i].
            #(Remember: when i=0, you are computing the derivative of the constant!)
            if i==0: 
                derivative=feature_derivative_ridge(errors, feature_matrix[:, i], weights[i],
                                                    l2_penalty, feature_is_constant=True)
            else:
                derivative=feature_derivative_ridge(errors, feature_matrix[:, i], weights[i],
                                                    l2_penalty, feature_is_constant=False)
            # subtract the step size times the derivative from the current weight
            weights[i] = weights[i] - step_size*derivative
    if print == True:
        print('Done with gradient descent at iteration ', iteration)
        print('Learned weights = ', str(weights))
    return weights

# %% [markdown]
# # Visualizing effect of L2 penalty

# %% [markdown]
# The L2 penalty gets its name because it causes weights to have small L2 norms than otherwise. Let's see how large weights get penalized. Let us consider a simple model with 1 feature:

# %%
simple_features =['sqft_living']
my_output = 'price'

# %% [markdown]
# Let us split the dataset into training set and test set. Make sure to use `seed=0`:

# %%
train_data = pd.read_csv('kc_house_train_data.csv')
test_data = pd.read_csv('kc_house_test_data.csv')

# %% [markdown]
# In this part, we will only use `'sqft_living'` to predict `'price'`. Use the `get_numpy_data` function to get a Numpy versions of your data with only this feature, for both the `train_data` and the `test_data`.

# %%
(simple_feature_matrix, output) = get_numpy_data(train_data, simple_features, my_output)
(simple_test_feature_matrix, test_output) = get_numpy_data(test_data, simple_features, my_output)

# %% [markdown]
# Let's set the parameters for our optimization:

# %%
initial_weights = np.array([0., 0.])
step_size = 1e-12
max_iterations=1000

# %% [markdown]
# First, let's consider no regularization.  Set the `l2_penalty` to `0.0` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `simple_weights_0_penalty`
#
# we'll use them later.

# %%
l2_penalty = 0.0
simple_weights_0_penalty = ridge_regression_gradient_descent(simple_feature_matrix, output, initial_weights, 
                                                             step_size, l2_penalty, print=False, max_iterations=100)

# %% [markdown]
# Next, let's consider high regularization.  Set the `l2_penalty` to `1e11` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `simple_weights_high_penalty`
#
# we'll use them later.

# %%
l2_penalty = 1e11
simple_weights_high_penalty = ridge_regression_gradient_descent(simple_feature_matrix, output, initial_weights, 
                                                             step_size, l2_penalty, max_iterations=1000)
# Out:
# Starting gradient descent with l2_penalty = 100000000000.0
# Iteration = 1
# Cost function =  7433051852335772.0
# Iteration = 2
# Cost function =  5618303898910948.0
# Iteration = 3
# Cost function =  4920613278301801.0
# Iteration = 4
# Cost function =  4652381942678799.0
# Iteration = 5
# Cost function =  4549258764034559.0
# Iteration = 6
# Cost function =  4509612390884944.0
# Iteration = 7
# Cost function =  4494370050276983.0
# Iteration = 8
# Cost function =  4488509984023467.0
# Iteration = 9
# Cost function =  4486256988524010.0
# Iteration = 10
# Cost function =  4485390752666540.0
# Iteration = 20
# Cost function =  4484848868025911.5
# Iteration = 30
# Cost function =  4484847880470642.0
# Iteration = 40
# Cost function =  4484846931073274.5
# Iteration = 50
# Cost function =  4484845981678999.0
# Iteration = 60
# Cost function =  4484845032285122.0
# Iteration = 70
# Cost function =  4484844082891643.5
# Iteration = 80
# Cost function =  4484843133498564.0
# Iteration = 90
# Cost function =  4484842184105883.0
# Iteration = 100
# Cost function =  4484841234713601.0
# Iteration = 200
# Cost function =  4484831740812717.0
# Iteration = 300
# Cost function =  4484822246951714.0
# Iteration = 400
# Cost function =  4484812753130591.0
# Iteration = 500
# Cost function =  4484803259349349.0
# Iteration = 600
# Cost function =  4484793765607986.0
# Iteration = 700
# Cost function =  4484784271906503.0
# Iteration = 800
# Cost function =  4484774778244900.0
# Iteration = 900
# Cost function =  4484765284623177.0
# Iteration = 1000
# Cost function =  4484755791041333.5
# Iteration = 1100
# Cost function =  4484746297499369.0
# Iteration = 1200
# Cost function =  4484736803997283.0
# Iteration = 1300
# Cost function =  4484727310535076.5
# Iteration = 1400
# Cost function =  4484717817112748.0
# Iteration = 1500
# Cost function =  4484708323730299.5
# Iteration = 1600
# Cost function =  4484698830387728.0
# Iteration = 1700
# Cost function =  4484689337085036.0
# Iteration = 1800
# Cost function =  4484679843822220.5
# Iteration = 1900
# Cost function =  4484670350599284.0
# Iteration = 2000
# Cost function =  4484660857416225.0
# Iteration = 2100
# Cost function =  4484651364273044.0
# Iteration = 2200
# Cost function =  4484641871169740.0
# Iteration = 2300
# Cost function =  4484632378106313.0
# Iteration = 2400
# Cost function =  4484622885082764.0
# Iteration = 2500
# Cost function =  4484613392099091.0
# Iteration = 2600
# Cost function =  4484603899155294.0
# Iteration = 2700
# Cost function =  4484594406251376.0
# Iteration = 2800
# Cost function =  4484584913387332.0
# Iteration = 2900
# Cost function =  4484575420563165.0
# Iteration = 3000
# Cost function =  4484565927778875.0
# Iteration = 3100
# Cost function =  4484556435034459.0
# Iteration = 3200
# Cost function =  4484546942329920.0
# Iteration = 3300
# Cost function =  4484537449665256.5
# Iteration = 3400
# Cost function =  4484527957040468.5
# Iteration = 3500
# Cost function =  4484518464455555.0
# Iteration = 3600
# Cost function =  4484508971910517.0
# Iteration = 3700
# Cost function =  4484499479405354.5
# Iteration = 3800
# Cost function =  4484489986940066.0
# Iteration = 3900
# Cost function =  4484480494514652.0
# Iteration = 4000
# Cost function =  4484471002129114.0
# Iteration = 4100
# Cost function =  4484461509783449.0
# Iteration = 4200
# Cost function =  4484452017477658.0
# Iteration = 4300
# Cost function =  4484442525211740.0
# Iteration = 4400
# Cost function =  4484433032985697.0
# Iteration = 4500
# Cost function =  4484423540799527.0
# Iteration = 4600
# Cost function =  4484414048653230.0
# Iteration = 4700
# Cost function =  4484404556546807.0
# Iteration = 4800
# Cost function =  4484395064480256.0
# Iteration = 4900
# Cost function =  4484385572453579.0
# Iteration = 5000
# Cost function =  4484376080466775.0
# Iteration = 5100
# Cost function =  4484366588519842.0
# Iteration = 5200
# Cost function =  4484357096612783.0
# Iteration = 5300
# Cost function =  4484347604745595.5
# Iteration = 5400
# Cost function =  4484338112918279.0
# Iteration = 5500
# Cost function =  4484328621130836.5
# Iteration = 5600
# Cost function =  4484319129383264.0
# Iteration = 5700
# Cost function =  4484309637675564.0
# Iteration = 5800
# Cost function =  4484300146007735.0
# Iteration = 5900
# Cost function =  4484290654379778.0
# Iteration = 6000
# Cost function =  4484281162791690.5
# Iteration = 6100
# Cost function =  4484271671243475.5
# Iteration = 6200
# Cost function =  4484262179735129.5
# Iteration = 6300
# Cost function =  4484252688266655.0
# Iteration = 6400
# Cost function =  4484243196838051.0
# Iteration = 6500
# Cost function =  4484233705449317.0
# Iteration = 6600
# Cost function =  4484224214100453.0
# Iteration = 6700
# Cost function =  4484214722791459.0
# Iteration = 6800
# Cost function =  4484205231522335.0
# Iteration = 6900
# Cost function =  4484195740293079.5
# Iteration = 7000
# Cost function =  4484186249103694.0
# Iteration = 7100
# Cost function =  4484176757954178.0
# Iteration = 7200
# Cost function =  4484167266844530.5
# Iteration = 7300
# Cost function =  4484157775774752.0
# Iteration = 7400
# Cost function =  4484148284744842.5
# Iteration = 7500
# Cost function =  4484138793754802.0
# Iteration = 7600
# Cost function =  4484129302804629.5
# Iteration = 7700
# Cost function =  4484119811894324.0
# Iteration = 7800
# Cost function =  4484110321023887.5
# Iteration = 7900
# Cost function =  4484100830193319.0
# Iteration = 8000
# Cost function =  4484091339402618.0
# Iteration = 8100
# Cost function =  4484081848651784.0
# Iteration = 8200
# Cost function =  4484072357940818.0
# Iteration = 8300
# Cost function =  4484062867269719.5
# Iteration = 8400
# Cost function =  4484053376638487.5
# Iteration = 8500
# Cost function =  4484043886047122.0
# Iteration = 8600
# Cost function =  4484034395495624.0
# Iteration = 8700
# Cost function =  4484024904983992.0
# Iteration = 8800
# Cost function =  4484015414512227.0
# Iteration = 8900
# Cost function =  4484005924080327.0
# Iteration = 9000
# Cost function =  4483996433688293.0
# Iteration = 9100
# Cost function =  4483986943336126.0
# Iteration = 9200
# Cost function =  4483977453023824.0
# Iteration = 9300
# Cost function =  4483967962751388.0
# Iteration = 9400
# Cost function =  4483958472518817.0
# Iteration = 9500
# Cost function =  4483948982326112.0
# Iteration = 9600
# Cost function =  4483939492173270.5
# Iteration = 9700
# Cost function =  4483930002060295.0
# Iteration = 9800
# Cost function =  4483920511987183.5
# Iteration = 9900
# Cost function =  4483911021953937.0
# Iteration = 10000
# Cost function =  4483901531960554.0
# Iteration = 10100
# Cost function =  4483892042007036.0
# Iteration = 10200
# Cost function =  4483882552093381.5
# Iteration = 10300
# Cost function =  4483873062219592.0
# Iteration = 10400
# Cost function =  4483863572385665.0
# Iteration = 10500
# Cost function =  4483854082591602.0
# Iteration = 10600
# Cost function =  4483844592837401.5
# Iteration = 10700
# Cost function =  4483835103123065.0
# Iteration = 10800
# Cost function =  4483825613448591.0
# Iteration = 10900
# Cost function =  4483816123813980.5
# Iteration = 11000
# Cost function =  4483806634219232.0
# Iteration = 11100
# Cost function =  4483797144664346.0
# Iteration = 11200
# Cost function =  4483787655149323.5
# Iteration = 11300
# Cost function =  4483778165674163.0
# Iteration = 11400
# Cost function =  4483768676238863.0
# Iteration = 11500
# Cost function =  4483759186843426.0
# Iteration = 11600
# Cost function =  4483749697487851.0
# Iteration = 11700
# Cost function =  4483740208172136.0
# Iteration = 11800
# Cost function =  4483730718896283.0
# Iteration = 11900
# Cost function =  4483721229660291.5
# Iteration = 12000
# Cost function =  4483711740464161.0
# Iteration = 12100
# Cost function =  4483702251307890.0
# Iteration = 12200
# Cost function =  4483692762191482.0
# Iteration = 12300
# Cost function =  4483683273114932.0
# Iteration = 12400
# Cost function =  4483673784078244.0
# Iteration = 12500
# Cost function =  4483664295081416.5
# Iteration = 12600
# Cost function =  4483654806124448.0
# Iteration = 12700
# Cost function =  4483645317207339.0
# Iteration = 12800
# Cost function =  4483635828330090.5
# Iteration = 12900
# Cost function =  4483626339492702.0
# Iteration = 13000
# Cost function =  4483616850695171.0
# Iteration = 13100
# Cost function =  4483607361937500.5
# Iteration = 13200
# Cost function =  4483597873219689.0
# Iteration = 13300
# Cost function =  4483588384541735.5
# Iteration = 13400
# Cost function =  4483578895903641.0
# Iteration = 13500
# Cost function =  4483569407305406.0
# Iteration = 13600
# Cost function =  4483559918747028.0
# Iteration = 13700
# Cost function =  4483550430228508.0
# Iteration = 13800
# Cost function =  4483540941749847.5
# Iteration = 13900
# Cost function =  4483531453311043.0
# Iteration = 14000
# Cost function =  4483521964912097.5
# Iteration = 14100
# Cost function =  4483512476553009.0
# Iteration = 14200
# Cost function =  4483502988233778.0
# Iteration = 14300
# Cost function =  4483493499954403.0
# Iteration = 14400
# Cost function =  4483484011714887.0
# Iteration = 14500
# Cost function =  4483474523515226.0
# Iteration = 14600
# Cost function =  4483465035355423.0
# Iteration = 14700
# Cost function =  4483455547235475.0
# Iteration = 14800
# Cost function =  4483446059155384.0
# Iteration = 14900
# Cost function =  4483436571115150.0
# Iteration = 15000
# Cost function =  4483427083114771.0
# Iteration = 15100
# Cost function =  4483417595154248.0
# Iteration = 15200
# Cost function =  4483408107233580.0
# Iteration = 15300
# Cost function =  4483398619352769.0
# Iteration = 15400
# Cost function =  4483389131511812.0
# Iteration = 15500
# Cost function =  4483379643710710.0
# Iteration = 15600
# Cost function =  4483370155949464.0
# Iteration = 15700
# Cost function =  4483360668228073.0
# Iteration = 15800
# Cost function =  4483351180546536.5
# Iteration = 15900
# Cost function =  4483341692904853.0
# Iteration = 16000
# Cost function =  4483332205303025.0
# Iteration = 16100
# Cost function =  4483322717741051.0
# Iteration = 16200
# Cost function =  4483313230218930.5
# Iteration = 16300
# Cost function =  4483303742736663.0
# Iteration = 16400
# Cost function =  4483294255294251.5
# Iteration = 16500
# Cost function =  4483284767891692.0
# Iteration = 16600
# Cost function =  4483275280528986.0
# Iteration = 16700
# Cost function =  4483265793206132.5
# Iteration = 16800
# Cost function =  4483256305923133.0
# Iteration = 16900
# Cost function =  4483246818679986.0
# Iteration = 17000
# Cost function =  4483237331476692.0
# Iteration = 17100
# Cost function =  4483227844313249.0
# Iteration = 17200
# Cost function =  4483218357189659.0
# Iteration = 17300
# Cost function =  4483208870105922.0
# Iteration = 17400
# Cost function =  4483199383062036.0
# Iteration = 17500
# Cost function =  4483189896058002.0
# Iteration = 17600
# Cost function =  4483180409093821.0
# Iteration = 17700
# Cost function =  4483170922169489.0
# Iteration = 17800
# Cost function =  4483161435285009.0
# Iteration = 17900
# Cost function =  4483151948440381.0
# Iteration = 18000
# Cost function =  4483142461635603.5
# Iteration = 18100
# Cost function =  4483132974870676.5
# Iteration = 18200
# Cost function =  4483123488145600.0
# Iteration = 18300
# Cost function =  4483114001460375.0
# Iteration = 18400
# Cost function =  4483104514815000.0
# Iteration = 18500
# Cost function =  4483095028209475.0
# Iteration = 18600
# Cost function =  4483085541643799.0
# Iteration = 18700
# Cost function =  4483076055117973.5
# Iteration = 18800
# Cost function =  4483066568631998.0
# Iteration = 18900
# Cost function =  4483057082185871.5
# Iteration = 19000
# Cost function =  4483047595779593.5
# Iteration = 19100
# Cost function =  4483038109413166.0
# Iteration = 19200
# Cost function =  4483028623086586.0
# Iteration = 19300
# Cost function =  4483019136799856.0
# Iteration = 19400
# Cost function =  4483009650552974.0
# Iteration = 19500
# Cost function =  4483000164345941.0
# Iteration = 19600
# Cost function =  4482990678178756.0
# Iteration = 19700
# Cost function =  4482981192051418.0
# Iteration = 19800
# Cost function =  4482971705963929.0
# Iteration = 19900
# Cost function =  4482962219916288.5
# Iteration = 20000
# Cost function =  4482952733908494.5
# Iteration = 20100
# Cost function =  4482943247940548.5
# Iteration = 20200
# Cost function =  4482933762012450.0
# Iteration = 20300
# Cost function =  4482924276124198.0
# Iteration = 20400
# Cost function =  4482914790275792.0
# Iteration = 20500
# Cost function =  4482905304467234.0
# Iteration = 20600
# Cost function =  4482895818698523.0
# Iteration = 20700
# Cost function =  4482886332969658.0
# Iteration = 20800
# Cost function =  4482876847280638.0
# Iteration = 20900
# Cost function =  4482867361631465.5
# Iteration = 21000
# Cost function =  4482857876022139.5
# Iteration = 21100
# Cost function =  4482848390452657.5
# Iteration = 21200
# Cost function =  4482838904923021.5
# Iteration = 21300
# Cost function =  4482829419433231.5
# Iteration = 21400
# Cost function =  4482819933983286.5
# Iteration = 21500
# Cost function =  4482810448573188.0
# Iteration = 21600
# Cost function =  4482800963202932.0
# Iteration = 21700
# Cost function =  4482791477872522.0
# Iteration = 21800
# Cost function =  4482781992581956.0
# Iteration = 21900
# Cost function =  4482772507331236.0
# Iteration = 22000
# Cost function =  4482763022120359.0
# Iteration = 22100
# Cost function =  4482753536949326.0
# Iteration = 22200
# Cost function =  4482744051818136.5
# Iteration = 22300
# Cost function =  4482734566726791.5
# Iteration = 22400
# Cost function =  4482725081675291.0
# Iteration = 22500
# Cost function =  4482715596663632.5
# Iteration = 22600
# Cost function =  4482706111691817.0
# Iteration = 22700
# Cost function =  4482696626759845.5
# Iteration = 22800
# Cost function =  4482687141867717.0
# Iteration = 22900
# Cost function =  4482677657015430.5
# Iteration = 23000
# Cost function =  4482668172202988.0
# Iteration = 23100
# Cost function =  4482658687430386.0
# Iteration = 23200
# Cost function =  4482649202697626.0
# Iteration = 23300
# Cost function =  4482639718004710.0
# Iteration = 23400
# Cost function =  4482630233351635.5
# Iteration = 23500
# Cost function =  4482620748738402.0
# Iteration = 23600
# Cost function =  4482611264165011.5
# Iteration = 23700
# Cost function =  4482601779631460.0
# Iteration = 23800
# Cost function =  4482592295137751.5
# Iteration = 23900
# Cost function =  4482582810683884.0
# Iteration = 24000
# Cost function =  4482573326269856.0
# Iteration = 24100
# Cost function =  4482563841895670.0
# Iteration = 24200
# Cost function =  4482554357561325.0
# Iteration = 24300
# Cost function =  4482544873266819.0
# Iteration = 24400
# Cost function =  4482535389012155.0
# Iteration = 24500
# Cost function =  4482525904797329.0
# Iteration = 24600
# Cost function =  4482516420622345.0
# Iteration = 24700
# Cost function =  4482506936487198.0
# Iteration = 24800
# Cost function =  4482497452391893.5
# Iteration = 24900
# Cost function =  4482487968336426.0
# Iteration = 25000
# Cost function =  4482478484320801.0
# Iteration = 25100
# Cost function =  4482469000345012.0
# Iteration = 25200
# Cost function =  4482459516409063.0
# Iteration = 25300
# Cost function =  4482450032512953.0
# Iteration = 25400
# Cost function =  4482440548656681.0
# Iteration = 25500
# Cost function =  4482431064840247.0
# Iteration = 25600
# Cost function =  4482421581063651.5
# Iteration = 25700
# Cost function =  4482412097326894.0
# Iteration = 25800
# Cost function =  4482402613629976.0
# Iteration = 25900
# Cost function =  4482393129972894.0
# Iteration = 26000
# Cost function =  4482383646355650.5
# Iteration = 26100
# Cost function =  4482374162778243.0
# Iteration = 26200
# Cost function =  4482364679240673.0
# Iteration = 26300
# Cost function =  4482355195742941.5
# Iteration = 26400
# Cost function =  4482345712285046.5
# Iteration = 26500
# Cost function =  4482336228866988.0
# Iteration = 26600
# Cost function =  4482326745488765.5
# Iteration = 26700
# Cost function =  4482317262150380.0
# Iteration = 26800
# Cost function =  4482307778851830.0
# Iteration = 26900
# Cost function =  4482298295593115.5
# Iteration = 27000
# Cost function =  4482288812374239.0
# Iteration = 27100
# Cost function =  4482279329195197.0
# Iteration = 27200
# Cost function =  4482269846055990.0
# Iteration = 27300
# Cost function =  4482260362956620.0
# Iteration = 27400
# Cost function =  4482250879897084.0
# Iteration = 27500
# Cost function =  4482241396877383.5
# Iteration = 27600
# Cost function =  4482231913897517.0
# Iteration = 27700
# Cost function =  4482222430957485.5
# Iteration = 27800
# Cost function =  4482212948057289.0
# Iteration = 27900
# Cost function =  4482203465196927.0
# Iteration = 28000
# Cost function =  4482193982376399.5
# Iteration = 28100
# Cost function =  4482184499595705.0
# Iteration = 28200
# Cost function =  4482175016854845.0
# Iteration = 28300
# Cost function =  4482165534153819.5
# Iteration = 28400
# Cost function =  4482156051492626.5
# Iteration = 28500
# Cost function =  4482146568871266.5
# Iteration = 28600
# Cost function =  4482137086289741.0
# Iteration = 28700
# Cost function =  4482127603748047.5
# Iteration = 28800
# Cost function =  4482118121246188.0
# Iteration = 28900
# Cost function =  4482108638784159.0
# Iteration = 29000
# Cost function =  4482099156361964.0
# Iteration = 29100
# Cost function =  4482089673979602.0
# Iteration = 29200
# Cost function =  4482080191637071.0
# Iteration = 29300
# Cost function =  4482070709334372.5
# Iteration = 29400
# Cost function =  4482061227071506.0
# Iteration = 29500
# Cost function =  4482051744848471.0
# Iteration = 29600
# Cost function =  4482042262665266.5
# Iteration = 29700
# Cost function =  4482032780521895.5
# Iteration = 29800
# Cost function =  4482023298418355.5
# Iteration = 29900
# Cost function =  4482013816354646.0
# Iteration = 30000
# Cost function =  4482004334330767.0
# Iteration = 30100
# Cost function =  4481994852346718.0
# Iteration = 30200
# Cost function =  4481985370402500.0
# Iteration = 30300
# Cost function =  4481975888498113.0
# Iteration = 30400
# Cost function =  4481966406633555.0
# Iteration = 30500
# Cost function =  4481956924808829.0
# Iteration = 30600
# Cost function =  4481947443023932.0
# Iteration = 30700
# Cost function =  4481937961278863.0
# Iteration = 30800
# Cost function =  4481928479573627.0
# Iteration = 30900
# Cost function =  4481918997908218.5
# Iteration = 31000
# Cost function =  4481909516282637.0
# Iteration = 31100
# Cost function =  4481900034696888.0
# Iteration = 31200
# Cost function =  4481890553150966.0
# Iteration = 31300
# Cost function =  4481881071644872.5
# Iteration = 31400
# Cost function =  4481871590178609.0
# Iteration = 31500
# Cost function =  4481862108752173.0
# Iteration = 31600
# Cost function =  4481852627365565.0
# Iteration = 31700
# Cost function =  4481843146018786.0
# Iteration = 31800
# Cost function =  4481833664711834.0
# Iteration = 31900
# Cost function =  4481824183444708.0
# Iteration = 32000
# Cost function =  4481814702217412.0
# Iteration = 32100
# Cost function =  4481805221029943.0
# Iteration = 32200
# Cost function =  4481795739882300.0
# Iteration = 32300
# Cost function =  4481786258774485.5
# Iteration = 32400
# Cost function =  4481776777706496.5
# Iteration = 32500
# Cost function =  4481767296678335.5
# Iteration = 32600
# Cost function =  4481757815690000.5
# Iteration = 32700
# Cost function =  4481748334741491.0
# Iteration = 32800
# Cost function =  4481738853832810.0
# Iteration = 32900
# Cost function =  4481729372963953.0
# Iteration = 33000
# Cost function =  4481719892134921.0
# Iteration = 33100
# Cost function =  4481710411345716.0
# Iteration = 33200
# Cost function =  4481700930596336.0
# Iteration = 33300
# Cost function =  4481691449886783.0
# Iteration = 33400
# Cost function =  4481681969217053.0
# Iteration = 33500
# Cost function =  4481672488587149.5
# Iteration = 33600
# Cost function =  4481663007997071.5
# Iteration = 33700
# Cost function =  4481653527446815.0
# Iteration = 33800
# Cost function =  4481644046936385.5
# Iteration = 33900
# Cost function =  4481634566465779.5
# Iteration = 34000
# Cost function =  4481625086034999.0
# Iteration = 34100
# Cost function =  4481615605644042.0
# Iteration = 34200
# Cost function =  4481606125292908.0
# Iteration = 34300
# Cost function =  4481596644981597.0
# Iteration = 34400
# Cost function =  4481587164710111.5
# Iteration = 34500
# Cost function =  4481577684478448.0
# Iteration = 34600
# Cost function =  4481568204286608.0
# Iteration = 34700
# Cost function =  4481558724134590.5
# Iteration = 34800
# Cost function =  4481549244022396.5
# Iteration = 34900
# Cost function =  4481539763950026.0
# Iteration = 35000
# Cost function =  4481530283917476.0
# Iteration = 35100
# Cost function =  4481520803924750.0
# Iteration = 35200
# Cost function =  4481511323971845.5
# Iteration = 35300
# Cost function =  4481501844058763.0
# Iteration = 35400
# Cost function =  4481492364185501.0
# Iteration = 35500
# Cost function =  4481482884352063.0
# Iteration = 35600
# Cost function =  4481473404558445.0
# Iteration = 35700
# Cost function =  4481463924804649.0
# Iteration = 35800
# Cost function =  4481454445090673.0
# Iteration = 35900
# Cost function =  4481444965416520.0
# Iteration = 36000
# Cost function =  4481435485782187.0
# Iteration = 36100
# Cost function =  4481426006187675.0
# Iteration = 36200
# Cost function =  4481416526632984.0
# Iteration = 36300
# Cost function =  4481407047118112.5
# Iteration = 36400
# Cost function =  4481397567643061.0
# Iteration = 36500
# Cost function =  4481388088207828.0
# Iteration = 36600
# Cost function =  4481378608812415.5
# Iteration = 36700
# Cost function =  4481369129456824.5
# Iteration = 36800
# Cost function =  4481359650141052.0
# Iteration = 36900
# Cost function =  4481350170865099.0
# Iteration = 37000
# Cost function =  4481340691628964.0
# Iteration = 37100
# Cost function =  4481331212432647.5
# Iteration = 37200
# Cost function =  4481321733276154.0
# Iteration = 37300
# Cost function =  4481312254159475.0
# Iteration = 37400
# Cost function =  4481302775082615.0
# Iteration = 37500
# Cost function =  4481293296045574.0
# Iteration = 37600
# Cost function =  4481283817048354.5
# Iteration = 37700
# Cost function =  4481274338090947.0
# Iteration = 37800
# Cost function =  4481264859173361.0
# Iteration = 37900
# Cost function =  4481255380295590.5
# Iteration = 38000
# Cost function =  4481245901457641.5
# Iteration = 38100
# Cost function =  4481236422659506.0
# Iteration = 38200
# Cost function =  4481226943901187.5
# Iteration = 38300
# Cost function =  4481217465182688.0
# Iteration = 38400
# Cost function =  4481207986504004.0
# Iteration = 38500
# Cost function =  4481198507865138.0
# Iteration = 38600
# Cost function =  4481189029266086.0
# Iteration = 38700
# Cost function =  4481179550706852.5
# Iteration = 38800
# Cost function =  4481170072187435.0
# Iteration = 38900
# Cost function =  4481160593707834.5
# Iteration = 39000
# Cost function =  4481151115268046.0
# Iteration = 39100
# Cost function =  4481141636868077.5
# Iteration = 39200
# Cost function =  4481132158507923.5
# Iteration = 39300
# Cost function =  4481122680187582.5
# Iteration = 39400
# Cost function =  4481113201907057.0
# Iteration = 39500
# Cost function =  4481103723666347.0
# Iteration = 39600
# Cost function =  4481094245465453.0
# Iteration = 39700
# Cost function =  4481084767304373.0
# Iteration = 39800
# Cost function =  4481075289183107.0
# Iteration = 39900
# Cost function =  4481065811101657.0
# Iteration = 40000
# Cost function =  4481056333060019.0
# Iteration = 40100
# Cost function =  4481046855058197.0
# Iteration = 40200
# Cost function =  4481037377096187.5
# Iteration = 40300
# Cost function =  4481027899173991.0
# Iteration = 40400
# Cost function =  4481018421291607.0
# Iteration = 40500
# Cost function =  4481008943449039.0
# Iteration = 40600
# Cost function =  4480999465646284.0
# Iteration = 40700
# Cost function =  4480989987883341.0
# Iteration = 40800
# Cost function =  4480980510160209.0
# Iteration = 40900
# Cost function =  4480971032476891.0
# Iteration = 41000
# Cost function =  4480961554833387.0
# Iteration = 41100
# Cost function =  4480952077229696.0
# Iteration = 41200
# Cost function =  4480942599665813.5
# Iteration = 41300
# Cost function =  4480933122141745.5
# Iteration = 41400
# Cost function =  4480923644657489.0
# Iteration = 41500
# Cost function =  4480914167213041.0
# Iteration = 41600
# Cost function =  4480904689808408.0
# Iteration = 41700
# Cost function =  4480895212443586.0
# Iteration = 41800
# Cost function =  4480885735118576.0
# Iteration = 41900
# Cost function =  4480876257833373.5
# Iteration = 42000
# Cost function =  4480866780587985.0
# Iteration = 42100
# Cost function =  4480857303382405.0
# Iteration = 42200
# Cost function =  4480847826216638.0
# Iteration = 42300
# Cost function =  4480838349090680.0
# Iteration = 42400
# Cost function =  4480828872004531.5
# Iteration = 42500
# Cost function =  4480819394958193.5
# Iteration = 42600
# Cost function =  4480809917951664.0
# Iteration = 42700
# Cost function =  4480800440984944.5
# Iteration = 42800
# Cost function =  4480790964058038.0
# Iteration = 42900
# Cost function =  4480781487170935.5
# Iteration = 43000
# Cost function =  4480772010323646.0
# Iteration = 43100
# Cost function =  4480762533516164.0
# Iteration = 43200
# Cost function =  4480753056748491.5
# Iteration = 43300
# Cost function =  4480743580020626.0
# Iteration = 43400
# Cost function =  4480734103332570.0
# Iteration = 43500
# Cost function =  4480724626684321.0
# Iteration = 43600
# Cost function =  4480715150075883.5
# Iteration = 43700
# Cost function =  4480705673507250.0
# Iteration = 43800
# Cost function =  4480696196978425.0
# Iteration = 43900
# Cost function =  4480686720489410.5
# Iteration = 44000
# Cost function =  4480677244040201.0
# Iteration = 44100
# Cost function =  4480667767630801.0
# Iteration = 44200
# Cost function =  4480658291261206.0
# Iteration = 44300
# Cost function =  4480648814931418.0
# Iteration = 44400
# Cost function =  4480639338641437.5
# Iteration = 44500
# Cost function =  4480629862391263.0
# Iteration = 44600
# Cost function =  4480620386180894.0
# Iteration = 44700
# Cost function =  4480610910010333.0
# Iteration = 44800
# Cost function =  4480601433879578.0
# Iteration = 44900
# Cost function =  4480591957788627.0
# Iteration = 45000
# Cost function =  4480582481737485.0
# Iteration = 45100
# Cost function =  4480573005726148.0
# Iteration = 45200
# Cost function =  4480563529754615.0
# Iteration = 45300
# Cost function =  4480554053822887.0
# Iteration = 45400
# Cost function =  4480544577930966.0
# Iteration = 45500
# Cost function =  4480535102078847.0
# Iteration = 45600
# Cost function =  4480525626266536.0
# Iteration = 45700
# Cost function =  4480516150494025.5
# Iteration = 45800
# Cost function =  4480506674761323.0
# Iteration = 45900
# Cost function =  4480497199068424.0
# Iteration = 46000
# Cost function =  4480487723415329.0
# Iteration = 46100
# Cost function =  4480478247802039.0
# Iteration = 46200
# Cost function =  4480468772228551.0
# Iteration = 46300
# Cost function =  4480459296694867.5
# Iteration = 46400
# Cost function =  4480449821200988.0
# Iteration = 46500
# Cost function =  4480440345746909.0
# Iteration = 46600
# Cost function =  4480430870332636.0
# Iteration = 46700
# Cost function =  4480421394958164.0
# Iteration = 46800
# Cost function =  4480411919623497.0
# Iteration = 46900
# Cost function =  4480402444328630.5
# Iteration = 47000
# Cost function =  4480392969073567.0
# Iteration = 47100
# Cost function =  4480383493858307.0
# Iteration = 47200
# Cost function =  4480374018682847.0
# Iteration = 47300
# Cost function =  4480364543547192.0
# Iteration = 47400
# Cost function =  4480355068451336.0
# Iteration = 47500
# Cost function =  4480345593395280.0
# Iteration = 47600
# Cost function =  4480336118379030.0
# Iteration = 47700
# Cost function =  4480326643402578.0
# Iteration = 47800
# Cost function =  4480317168465930.0
# Iteration = 47900
# Cost function =  4480307693569080.0
# Iteration = 48000
# Cost function =  4480298218712032.0
# Iteration = 48100
# Cost function =  4480288743894786.0
# Iteration = 48200
# Cost function =  4480279269117338.0
# Iteration = 48300
# Cost function =  4480269794379689.0
# Iteration = 48400
# Cost function =  4480260319681845.0
# Iteration = 48500
# Cost function =  4480250845023796.5
# Iteration = 48600
# Cost function =  4480241370405549.0
# Iteration = 48700
# Cost function =  4480231895827103.0
# Iteration = 48800
# Cost function =  4480222421288455.5
# Iteration = 48900
# Cost function =  4480212946789606.0
# Iteration = 49000
# Cost function =  4480203472330558.0
# Iteration = 49100
# Cost function =  4480193997911305.5
# Iteration = 49200
# Cost function =  4480184523531852.5
# Iteration = 49300
# Cost function =  4480175049192200.0
# Iteration = 49400
# Cost function =  4480165574892345.0
# Iteration = 49500
# Cost function =  4480156100632288.0
# Iteration = 49600
# Cost function =  4480146626412030.0
# Iteration = 49700
# Cost function =  4480137152231567.0
# Iteration = 49800
# Cost function =  4480127678090904.0
# Iteration = 49900
# Cost function =  4480118203990041.0
# Iteration = 50000
# Cost function =  4480108729928973.0
# Iteration = 50100
# Cost function =  4480099255907700.0
# Iteration = 50200
# Cost function =  4480089781926228.0
# Iteration = 50300
# Cost function =  4480080307984549.0
# Iteration = 50400
# Cost function =  4480070834082670.0
# Iteration = 50500
# Cost function =  4480061360220588.0
# Iteration = 50600
# Cost function =  4480051886398298.5
# Iteration = 50700
# Cost function =  4480042412615808.0
# Iteration = 50800
# Cost function =  4480032938873114.5
# Iteration = 50900
# Cost function =  4480023465170216.0
# Iteration = 51000
# Cost function =  4480013991507115.0
# Iteration = 51100
# Cost function =  4480004517883803.0
# Iteration = 51200
# Cost function =  4479995044300291.5
# Iteration = 51300
# Cost function =  4479985570756577.0
# Iteration = 51400
# Cost function =  4479976097252655.0
# Iteration = 51500
# Cost function =  4479966623788524.0
# Iteration = 51600
# Cost function =  4479957150364194.0
# Iteration = 51700
# Cost function =  4479947676979660.0
# Iteration = 51800
# Cost function =  4479938203634914.0
# Iteration = 51900
# Cost function =  4479928730329963.0
# Iteration = 52000
# Cost function =  4479919257064809.0
# Iteration = 52100
# Cost function =  4479909783839452.0
# Iteration = 52200
# Cost function =  4479900310653884.0
# Iteration = 52300
# Cost function =  4479890837508108.0
# Iteration = 52400
# Cost function =  4479881364402131.5
# Iteration = 52500
# Cost function =  4479871891335941.0
# Iteration = 52600
# Cost function =  4479862418309546.0
# Iteration = 52700
# Cost function =  4479852945322947.0
# Iteration = 52800
# Cost function =  4479843472376140.0
# Iteration = 52900
# Cost function =  4479833999469123.0
# Iteration = 53000
# Cost function =  4479824526601902.5
# Iteration = 53100
# Cost function =  4479815053774468.0
# Iteration = 53200
# Cost function =  4479805580986829.0
# Iteration = 53300
# Cost function =  4479796108238981.5
# Iteration = 53400
# Cost function =  4479786635530930.0
# Iteration = 53500
# Cost function =  4479777162862663.5
# Iteration = 53600
# Cost function =  4479767690234192.5
# Iteration = 53700
# Cost function =  4479758217645511.0
# Iteration = 53800
# Cost function =  4479748745096621.0
# Iteration = 53900
# Cost function =  4479739272587521.5
# Iteration = 54000
# Cost function =  4479729800118210.0
# Iteration = 54100
# Cost function =  4479720327688695.0
# Iteration = 54200
# Cost function =  4479710855298965.0
# Iteration = 54300
# Cost function =  4479701382949028.0
# Iteration = 54400
# Cost function =  4479691910638883.0
# Iteration = 54500
# Cost function =  4479682438368526.0
# Iteration = 54600
# Cost function =  4479672966137959.0
# Iteration = 54700
# Cost function =  4479663493947181.0
# Iteration = 54800
# Cost function =  4479654021796192.0
# Iteration = 54900
# Cost function =  4479644549684991.0
# Iteration = 55000
# Cost function =  4479635077613580.0
# Iteration = 55100
# Cost function =  4479625605581957.0
# Iteration = 55200
# Cost function =  4479616133590124.5
# Iteration = 55300
# Cost function =  4479606661638084.0
# Iteration = 55400
# Cost function =  4479597189725827.0
# Iteration = 55500
# Cost function =  4479587717853359.0
# Iteration = 55600
# Cost function =  4479578246020678.5
# Iteration = 55700
# Cost function =  4479568774227786.0
# Iteration = 55800
# Cost function =  4479559302474681.5
# Iteration = 55900
# Cost function =  4479549830761365.0
# Iteration = 56000
# Cost function =  4479540359087837.0
# Iteration = 56100
# Cost function =  4479530887454096.5
# Iteration = 56200
# Cost function =  4479521415860144.0
# Iteration = 56300
# Cost function =  4479511944305972.5
# Iteration = 56400
# Cost function =  4479502472791594.5
# Iteration = 56500
# Cost function =  4479493001316998.0
# Iteration = 56600
# Cost function =  4479483529882189.0
# Iteration = 56700
# Cost function =  4479474058487166.0
# Iteration = 56800
# Cost function =  4479464587131931.0
# Iteration = 56900
# Cost function =  4479455115816482.5
# Iteration = 57000
# Cost function =  4479445644540815.5
# Iteration = 57100
# Cost function =  4479436173304941.0
# Iteration = 57200
# Cost function =  4479426702108847.0
# Iteration = 57300
# Cost function =  4479417230952539.0
# Iteration = 57400
# Cost function =  4479407759836011.0
# Iteration = 57500
# Cost function =  4479398288759276.5
# Iteration = 57600
# Cost function =  4479388817722322.0
# Iteration = 57700
# Cost function =  4479379346725153.5
# Iteration = 57800
# Cost function =  4479369875767771.0
# Iteration = 57900
# Cost function =  4479360404850169.0
# Iteration = 58000
# Cost function =  4479350933972351.5
# Iteration = 58100
# Cost function =  4479341463134320.0
# Iteration = 58200
# Cost function =  4479331992336070.0
# Iteration = 58300
# Cost function =  4479322521577603.5
# Iteration = 58400
# Cost function =  4479313050858923.0
# Iteration = 58500
# Cost function =  4479303580180027.0
# Iteration = 58600
# Cost function =  4479294109540911.0
# Iteration = 58700
# Cost function =  4479284638941575.0
# Iteration = 58800
# Cost function =  4479275168382029.0
# Iteration = 58900
# Cost function =  4479265697862256.0
# Iteration = 59000
# Cost function =  4479256227382273.5
# Iteration = 59100
# Cost function =  4479246756942071.0
# Iteration = 59200
# Cost function =  4479237286541652.0
# Iteration = 59300
# Cost function =  4479227816181010.5
# Iteration = 59400
# Cost function =  4479218345860154.0
# Iteration = 59500
# Cost function =  4479208875579077.0
# Iteration = 59600
# Cost function =  4479199405337784.0
# Iteration = 59700
# Cost function =  4479189935136268.0
# Iteration = 59800
# Cost function =  4479180464974536.0
# Iteration = 59900
# Cost function =  4479170994852588.5
# Iteration = 60000
# Cost function =  4479161524770413.0
# Iteration = 60100
# Cost function =  4479152054728026.5
# Iteration = 60200
# Cost function =  4479142584725418.0
# Iteration = 60300
# Cost function =  4479133114762587.0
# Iteration = 60400
# Cost function =  4479123644839539.0
# Iteration = 60500
# Cost function =  4479114174956269.0
# Iteration = 60600
# Cost function =  4479104705112776.0
# Iteration = 60700
# Cost function =  4479095235309065.0
# Iteration = 60800
# Cost function =  4479085765545138.0
# Iteration = 60900
# Cost function =  4479076295820982.5
# Iteration = 61000
# Cost function =  4479066826136614.0
# Iteration = 61100
# Cost function =  4479057356492017.5
# Iteration = 61200
# Cost function =  4479047886887203.0
# Iteration = 61300
# Cost function =  4479038417322165.0
# Iteration = 61400
# Cost function =  4479028947796909.5
# Iteration = 61500
# Cost function =  4479019478311431.0
# Iteration = 61600
# Cost function =  4479010008865726.5
# Iteration = 61700
# Cost function =  4479000539459800.0
# Iteration = 61800
# Cost function =  4478991070093654.0
# Iteration = 61900
# Cost function =  4478981600767286.0
# Iteration = 62000
# Cost function =  4478972131480691.5
# Iteration = 62100
# Cost function =  4478962662233880.0
# Iteration = 62200
# Cost function =  4478953193026844.0
# Iteration = 62300
# Cost function =  4478943723859583.0
# Iteration = 62400
# Cost function =  4478934254732098.0
# Iteration = 62500
# Cost function =  4478924785644393.0
# Iteration = 62600
# Cost function =  4478915316596458.0
# Iteration = 62700
# Cost function =  4478905847588304.0
# Iteration = 62800
# Cost function =  4478896378619924.5
# Iteration = 62900
# Cost function =  4478886909691321.0
# Iteration = 63000
# Cost function =  4478877440802496.5
# Iteration = 63100
# Cost function =  4478867971953442.0
# Iteration = 63200
# Cost function =  4478858503144167.0
# Iteration = 63300
# Cost function =  4478849034374666.5
# Iteration = 63400
# Cost function =  4478839565644941.0
# Iteration = 63500
# Cost function =  4478830096954989.5
# Iteration = 63600
# Cost function =  4478820628304813.0
# Iteration = 63700
# Cost function =  4478811159694409.0
# Iteration = 63800
# Cost function =  4478801691123780.0
# Iteration = 63900
# Cost function =  4478792222592930.0
# Iteration = 64000
# Cost function =  4478782754101849.0
# Iteration = 64100
# Cost function =  4478773285650546.0
# Iteration = 64200
# Cost function =  4478763817239012.0
# Iteration = 64300
# Cost function =  4478754348867250.0
# Iteration = 64400
# Cost function =  4478744880535268.0
# Iteration = 64500
# Cost function =  4478735412243054.0
# Iteration = 64600
# Cost function =  4478725943990618.0
# Iteration = 64700
# Cost function =  4478716475777950.0
# Iteration = 64800
# Cost function =  4478707007605059.0
# Iteration = 64900
# Cost function =  4478697539471936.0
# Iteration = 65000
# Cost function =  4478688071378587.0
# Iteration = 65100
# Cost function =  4478678603325009.5
# Iteration = 65200
# Cost function =  4478669135311210.0
# Iteration = 65300
# Cost function =  4478659667337176.5
# Iteration = 65400
# Cost function =  4478650199402916.0
# Iteration = 65500
# Cost function =  4478640731508422.0
# Iteration = 65600
# Cost function =  4478631263653706.0
# Iteration = 65700
# Cost function =  4478621795838762.0
# Iteration = 65800
# Cost function =  4478612328063583.0
# Iteration = 65900
# Cost function =  4478602860328177.0
# Iteration = 66000
# Cost function =  4478593392632542.0
# Iteration = 66100
# Cost function =  4478583924976679.0
# Iteration = 66200
# Cost function =  4478574457360588.0
# Iteration = 66300
# Cost function =  4478564989784266.5
# Iteration = 66400
# Cost function =  4478555522247711.5
# Iteration = 66500
# Cost function =  4478546054750928.0
# Iteration = 66600
# Cost function =  4478536587293915.0
# Iteration = 66700
# Cost function =  4478527119876667.0
# Iteration = 66800
# Cost function =  4478517652499197.0
# Iteration = 66900
# Cost function =  4478508185161491.0
# Iteration = 67000
# Cost function =  4478498717863554.5
# Iteration = 67100
# Cost function =  4478489250605383.0
# Iteration = 67200
# Cost function =  4478479783386983.0
# Iteration = 67300
# Cost function =  4478470316208354.0
# Iteration = 67400
# Cost function =  4478460849069494.0
# Iteration = 67500
# Cost function =  4478451381970398.0
# Iteration = 67600
# Cost function =  4478441914911072.0
# Iteration = 67700
# Cost function =  4478432447891517.0
# Iteration = 67800
# Cost function =  4478422980911725.0
# Iteration = 67900
# Cost function =  4478413513971697.0
# Iteration = 68000
# Cost function =  4478404047071444.0
# Iteration = 68100
# Cost function =  4478394580210956.0
# Iteration = 68200
# Cost function =  4478385113390236.5
# Iteration = 68300
# Cost function =  4478375646609280.5
# Iteration = 68400
# Cost function =  4478366179868093.0
# Iteration = 68500
# Cost function =  4478356713166670.0
# Iteration = 68600
# Cost function =  4478347246505016.0
# Iteration = 68700
# Cost function =  4478337779883124.0
# Iteration = 68800
# Cost function =  4478328313301002.0
# Iteration = 68900
# Cost function =  4478318846758647.0
# Iteration = 69000
# Cost function =  4478309380256049.5
# Iteration = 69100
# Cost function =  4478299913793226.5
# Iteration = 69200
# Cost function =  4478290447370166.5
# Iteration = 69300
# Cost function =  4478280980986868.5
# Iteration = 69400
# Cost function =  4478271514643338.0
# Iteration = 69500
# Cost function =  4478262048339571.5
# Iteration = 69600
# Cost function =  4478252582075571.0
# Iteration = 69700
# Cost function =  4478243115851333.0
# Iteration = 69800
# Cost function =  4478233649666863.5
# Iteration = 69900
# Cost function =  4478224183522155.0
# Iteration = 70000
# Cost function =  4478214717417209.0
# Iteration = 70100
# Cost function =  4478205251352030.0
# Iteration = 70200
# Cost function =  4478195785326613.0
# Iteration = 70300
# Cost function =  4478186319340962.0
# Iteration = 70400
# Cost function =  4478176853395073.5
# Iteration = 70500
# Cost function =  4478167387488945.0
# Iteration = 70600
# Cost function =  4478157921622578.5
# Iteration = 70700
# Cost function =  4478148455795977.5
# Iteration = 70800
# Cost function =  4478138990009139.0
# Iteration = 70900
# Cost function =  4478129524262066.0
# Iteration = 71000
# Cost function =  4478120058554749.0
# Iteration = 71100
# Cost function =  4478110592887204.0
# Iteration = 71200
# Cost function =  4478101127259412.0
# Iteration = 71300
# Cost function =  4478091661671381.5
# Iteration = 71400
# Cost function =  4478082196123118.0
# Iteration = 71500
# Cost function =  4478072730614613.0
# Iteration = 71600
# Cost function =  4478063265145869.0
# Iteration = 71700
# Cost function =  4478053799716890.0
# Iteration = 71800
# Cost function =  4478044334327666.5
# Iteration = 71900
# Cost function =  4478034868978206.5
# Iteration = 72000
# Cost function =  4478025403668507.0
# Iteration = 72100
# Cost function =  4478015938398568.0
# Iteration = 72200
# Cost function =  4478006473168393.0
# Iteration = 72300
# Cost function =  4477997007977972.0
# Iteration = 72400
# Cost function =  4477987542827316.0
# Iteration = 72500
# Cost function =  4477978077716413.0
# Iteration = 72600
# Cost function =  4477968612645276.0
# Iteration = 72700
# Cost function =  4477959147613896.0
# Iteration = 72800
# Cost function =  4477949682622276.0
# Iteration = 72900
# Cost function =  4477940217670415.5
# Iteration = 73000
# Cost function =  4477930752758311.0
# Iteration = 73100
# Cost function =  4477921287885973.5
# Iteration = 73200
# Cost function =  4477911823053387.0
# Iteration = 73300
# Cost function =  4477902358260564.5
# Iteration = 73400
# Cost function =  4477892893507495.0
# Iteration = 73500
# Cost function =  4477883428794184.0
# Iteration = 73600
# Cost function =  4477873964120636.0
# Iteration = 73700
# Cost function =  4477864499486840.0
# Iteration = 73800
# Cost function =  4477855034892802.0
# Iteration = 73900
# Cost function =  4477845570338522.0
# Iteration = 74000
# Cost function =  4477836105824005.5
# Iteration = 74100
# Cost function =  4477826641349234.5
# Iteration = 74200
# Cost function =  4477817176914232.5
# Iteration = 74300
# Cost function =  4477807712518976.0
# Iteration = 74400
# Cost function =  4477798248163489.0
# Iteration = 74500
# Cost function =  4477788783847746.5
# Iteration = 74600
# Cost function =  4477779319571767.0
# Iteration = 74700
# Cost function =  4477769855335538.0
# Iteration = 74800
# Cost function =  4477760391139072.0
# Iteration = 74900
# Cost function =  4477750926982356.0
# Iteration = 75000
# Cost function =  4477741462865404.0
# Iteration = 75100
# Cost function =  4477731998788202.0
# Iteration = 75200
# Cost function =  4477722534750750.0
# Iteration = 75300
# Cost function =  4477713070753061.0
# Iteration = 75400
# Cost function =  4477703606795121.0
# Iteration = 75500
# Cost function =  4477694142876944.0
# Iteration = 75600
# Cost function =  4477684678998516.0
# Iteration = 75700
# Cost function =  4477675215159850.5
# Iteration = 75800
# Cost function =  4477665751360923.0
# Iteration = 75900
# Cost function =  4477656287601768.0
# Iteration = 76000
# Cost function =  4477646823882352.0
# Iteration = 76100
# Cost function =  4477637360202697.0
# Iteration = 76200
# Cost function =  4477627896562790.0
# Iteration = 76300
# Cost function =  4477618432962645.5
# Iteration = 76400
# Cost function =  4477608969402250.0
# Iteration = 76500
# Cost function =  4477599505881603.0
# Iteration = 76600
# Cost function =  4477590042400718.0
# Iteration = 76700
# Cost function =  4477580578959581.0
# Iteration = 76800
# Cost function =  4477571115558193.0
# Iteration = 76900
# Cost function =  4477561652196566.0
# Iteration = 77000
# Cost function =  4477552188874686.0
# Iteration = 77100
# Cost function =  4477542725592556.0
# Iteration = 77200
# Cost function =  4477533262350185.5
# Iteration = 77300
# Cost function =  4477523799147552.0
# Iteration = 77400
# Cost function =  4477514335984690.0
# Iteration = 77500
# Cost function =  4477504872861564.0
# Iteration = 77600
# Cost function =  4477495409778198.0
# Iteration = 77700
# Cost function =  4477485946734580.0
# Iteration = 77800
# Cost function =  4477476483730709.0
# Iteration = 77900
# Cost function =  4477467020766587.0
# Iteration = 78000
# Cost function =  4477457557842223.5
# Iteration = 78100
# Cost function =  4477448094957607.0
# Iteration = 78200
# Cost function =  4477438632112751.0
# Iteration = 78300
# Cost function =  4477429169307629.0
# Iteration = 78400
# Cost function =  4477419706542267.0
# Iteration = 78500
# Cost function =  4477410243816651.0
# Iteration = 78600
# Cost function =  4477400781130783.5
# Iteration = 78700
# Cost function =  4477391318484673.0
# Iteration = 78800
# Cost function =  4477381855878298.0
# Iteration = 78900
# Cost function =  4477372393311682.0
# Iteration = 79000
# Cost function =  4477362930784813.0
# Iteration = 79100
# Cost function =  4477353468297700.5
# Iteration = 79200
# Cost function =  4477344005850323.0
# Iteration = 79300
# Cost function =  4477334543442704.0
# Iteration = 79400
# Cost function =  4477325081074831.0
# Iteration = 79500
# Cost function =  4477315618746705.0
# Iteration = 79600
# Cost function =  4477306156458323.5
# Iteration = 79700
# Cost function =  4477296694209689.0
# Iteration = 79800
# Cost function =  4477287232000811.0
# Iteration = 79900
# Cost function =  4477277769831679.0
# Iteration = 80000
# Cost function =  4477268307702292.0
# Iteration = 80100
# Cost function =  4477258845612651.0
# Iteration = 80200
# Cost function =  4477249383562755.0
# Iteration = 80300
# Cost function =  4477239921552604.0
# Iteration = 80400
# Cost function =  4477230459582199.0
# Iteration = 80500
# Cost function =  4477220997651550.0
# Iteration = 80600
# Cost function =  4477211535760646.0
# Iteration = 80700
# Cost function =  4477202073909475.0
# Iteration = 80800
# Cost function =  4477192612098061.0
# Iteration = 80900
# Cost function =  4477183150326390.5
# Iteration = 81000
# Cost function =  4477173688594465.0
# Iteration = 81100
# Cost function =  4477164226902297.0
# Iteration = 81200
# Cost function =  4477154765249859.0
# Iteration = 81300
# Cost function =  4477145303637167.0
# Iteration = 81400
# Cost function =  4477135842064230.0
# Iteration = 81500
# Cost function =  4477126380531026.0
# Iteration = 81600
# Cost function =  4477116919037577.0
# Iteration = 81700
# Cost function =  4477107457583860.5
# Iteration = 81800
# Cost function =  4477097996169899.0
# Iteration = 81900
# Cost function =  4477088534795681.0
# Iteration = 82000
# Cost function =  4477079073461195.0
# Iteration = 82100
# Cost function =  4477069612166464.5
# Iteration = 82200
# Cost function =  4477060150911477.0
# Iteration = 82300
# Cost function =  4477050689696231.5
# Iteration = 82400
# Cost function =  4477041228520729.5
# Iteration = 82500
# Cost function =  4477031767384970.5
# Iteration = 82600
# Cost function =  4477022306288944.0
# Iteration = 82700
# Cost function =  4477012845232671.0
# Iteration = 82800
# Cost function =  4477003384216141.0
# Iteration = 82900
# Cost function =  4476993923239352.0
# Iteration = 83000
# Cost function =  4476984462302306.0
# Iteration = 83100
# Cost function =  4476975001405003.0
# Iteration = 83200
# Cost function =  4476965540547442.5
# Iteration = 83300
# Cost function =  4476956079729623.5
# Iteration = 83400
# Cost function =  4476946618951535.0
# Iteration = 83500
# Cost function =  4476937158213201.0
# Iteration = 83600
# Cost function =  4476927697514607.0
# Iteration = 83700
# Cost function =  4476918236855744.5
# Iteration = 83800
# Cost function =  4476908776236635.0
# Iteration = 83900
# Cost function =  4476899315657255.0
# Iteration = 84000
# Cost function =  4476889855117628.0
# Iteration = 84100
# Cost function =  4476880394617730.0
# Iteration = 84200
# Cost function =  4476870934157585.5
# Iteration = 84300
# Cost function =  4476861473737170.0
# Iteration = 84400
# Cost function =  4476852013356497.0
# Iteration = 84500
# Cost function =  4476842553015563.5
# Iteration = 84600
# Cost function =  4476833092714371.0
# Iteration = 84700
# Cost function =  4476823632452919.0
# Iteration = 84800
# Cost function =  4476814172231208.0
# Iteration = 84900
# Cost function =  4476804712049227.0
# Iteration = 85000
# Cost function =  4476795251906996.0
# Iteration = 85100
# Cost function =  4476785791804493.5
# Iteration = 85200
# Cost function =  4476776331741732.5
# Iteration = 85300
# Cost function =  4476766871718711.5
# Iteration = 85400
# Cost function =  4476757411735429.5
# Iteration = 85500
# Cost function =  4476747951791887.5
# Iteration = 85600
# Cost function =  4476738491888086.0
# Iteration = 85700
# Cost function =  4476729032024011.0
# Iteration = 85800
# Cost function =  4476719572199688.0
# Iteration = 85900
# Cost function =  4476710112415094.5
# Iteration = 86000
# Cost function =  4476700652670238.0
# Iteration = 86100
# Cost function =  4476691192965110.0
# Iteration = 86200
# Cost function =  4476681733299733.0
# Iteration = 86300
# Cost function =  4476672273674083.0
# Iteration = 86400
# Cost function =  4476662814088183.5
# Iteration = 86500
# Cost function =  4476653354542011.0
# Iteration = 86600
# Cost function =  4476643895035566.0
# Iteration = 86700
# Cost function =  4476634435568870.5
# Iteration = 86800
# Cost function =  4476624976141903.0
# Iteration = 86900
# Cost function =  4476615516754684.0
# Iteration = 87000
# Cost function =  4476606057407193.5
# Iteration = 87100
# Cost function =  4476596598099428.0
# Iteration = 87200
# Cost function =  4476587138831412.5
# Iteration = 87300
# Cost function =  4476577679603124.0
# Iteration = 87400
# Cost function =  4476568220414572.5
# Iteration = 87500
# Cost function =  4476558761265749.0
# Iteration = 87600
# Cost function =  4476549302156673.0
# Iteration = 87700
# Cost function =  4476539843087323.0
# Iteration = 87800
# Cost function =  4476530384057711.0
# Iteration = 87900
# Cost function =  4476520925067837.0
# Iteration = 88000
# Cost function =  4476511466117687.0
# Iteration = 88100
# Cost function =  4476502007207274.0
# Iteration = 88200
# Cost function =  4476492548336600.0
# Iteration = 88300
# Cost function =  4476483089505650.0
# Iteration = 88400
# Cost function =  4476473630714438.0
# Iteration = 88500
# Cost function =  4476464171962961.5
# Iteration = 88600
# Cost function =  4476454713251210.0
# Iteration = 88700
# Cost function =  4476445254579207.5
# Iteration = 88800
# Cost function =  4476435795946918.0
# Iteration = 88900
# Cost function =  4476426337354376.0
# Iteration = 89000
# Cost function =  4476416878801560.0
# Iteration = 89100
# Cost function =  4476407420288477.0
# Iteration = 89200
# Cost function =  4476397961815121.0
# Iteration = 89300
# Cost function =  4476388503381512.0
# Iteration = 89400
# Cost function =  4476379044987616.0
# Iteration = 89500
# Cost function =  4476369586633466.5
# Iteration = 89600
# Cost function =  4476360128319041.0
# Iteration = 89700
# Cost function =  4476350670044339.0
# Iteration = 89800
# Cost function =  4476341211809385.0
# Iteration = 89900
# Cost function =  4476331753614142.0
# Iteration = 90000
# Cost function =  4476322295458647.0
# Iteration = 90100
# Cost function =  4476312837342875.5
# Iteration = 90200
# Cost function =  4476303379266838.0
# Iteration = 90300
# Cost function =  4476293921230524.0
# Iteration = 90400
# Cost function =  4476284463233944.5
# Iteration = 90500
# Cost function =  4476275005277089.0
# Iteration = 90600
# Cost function =  4476265547359967.0
# Iteration = 90700
# Cost function =  4476256089482579.0
# Iteration = 90800
# Cost function =  4476246631644915.0
# Iteration = 90900
# Cost function =  4476237173846986.0
# Iteration = 91000
# Cost function =  4476227716088777.0
# Iteration = 91100
# Cost function =  4476218258370305.0
# Iteration = 91200
# Cost function =  4476208800691553.0
# Iteration = 91300
# Cost function =  4476199343052535.0
# Iteration = 91400
# Cost function =  4476189885453240.0
# Iteration = 91500
# Cost function =  4476180427893678.5
# Iteration = 91600
# Cost function =  4476170970373838.5
# Iteration = 91700
# Cost function =  4476161512893732.0
# Iteration = 91800
# Cost function =  4476152055453359.0
# Iteration = 91900
# Cost function =  4476142598052708.0
# Iteration = 92000
# Cost function =  4476133140691777.5
# Iteration = 92100
# Cost function =  4476123683370581.0
# Iteration = 92200
# Cost function =  4476114226089117.0
# Iteration = 92300
# Cost function =  4476104768847363.0
# Iteration = 92400
# Cost function =  4476095311645352.5
# Iteration = 92500
# Cost function =  4476085854483063.5
# Iteration = 92600
# Cost function =  4476076397360494.5
# Iteration = 92700
# Cost function =  4476066940277659.0
# Iteration = 92800
# Cost function =  4476057483234543.0
# Iteration = 92900
# Cost function =  4476048026231161.0
# Iteration = 93000
# Cost function =  4476038569267498.0
# Iteration = 93100
# Cost function =  4476029112343556.0
# Iteration = 93200
# Cost function =  4476019655459345.0
# Iteration = 93300
# Cost function =  4476010198614866.0
# Iteration = 93400
# Cost function =  4476000741810107.0
# Iteration = 93500
# Cost function =  4475991285045068.0
# Iteration = 93600
# Cost function =  4475981828319762.0
# Iteration = 93700
# Cost function =  4475972371634175.0
# Iteration = 93800
# Cost function =  4475962914988305.5
# Iteration = 93900
# Cost function =  4475953458382169.5
# Iteration = 94000
# Cost function =  4475944001815752.0
# Iteration = 94100
# Cost function =  4475934545289065.5
# Iteration = 94200
# Cost function =  4475925088802098.5
# Iteration = 94300
# Cost function =  4475915632354851.0
# Iteration = 94400
# Cost function =  4475906175947333.0
# Iteration = 94500
# Cost function =  4475896719579535.0
# Iteration = 94600
# Cost function =  4475887263251455.0
# Iteration = 94700
# Cost function =  4475877806963105.5
# Iteration = 94800
# Cost function =  4475868350714475.0
# Iteration = 94900
# Cost function =  4475858894505574.0
# Iteration = 95000
# Cost function =  4475849438336392.0
# Iteration = 95100
# Cost function =  4475839982206927.0
# Iteration = 95200
# Cost function =  4475830526117182.0
# Iteration = 95300
# Cost function =  4475821070067166.0
# Iteration = 95400
# Cost function =  4475811614056867.5
# Iteration = 95500
# Cost function =  4475802158086299.0
# Iteration = 95600
# Cost function =  4475792702155436.5
# Iteration = 95700
# Cost function =  4475783246264303.0
# Iteration = 95800
# Cost function =  4475773790412899.5
# Iteration = 95900
# Cost function =  4475764334601201.0
# Iteration = 96000
# Cost function =  4475754878829231.0
# Iteration = 96100
# Cost function =  4475745423096978.5
# Iteration = 96200
# Cost function =  4475735967404456.0
# Iteration = 96300
# Cost function =  4475726511751637.0
# Iteration = 96400
# Cost function =  4475717056138548.5
# Iteration = 96500
# Cost function =  4475707600565176.0
# Iteration = 96600
# Cost function =  4475698145031531.5
# Iteration = 96700
# Cost function =  4475688689537593.0
# Iteration = 96800
# Cost function =  4475679234083381.0
# Iteration = 96900
# Cost function =  4475669778668887.0
# Iteration = 97000
# Cost function =  4475660323294120.0
# Iteration = 97100
# Cost function =  4475650867959058.5
# Iteration = 97200
# Cost function =  4475641412663724.5
# Iteration = 97300
# Cost function =  4475631957408105.5
# Iteration = 97400
# Cost function =  4475622502192203.0
# Iteration = 97500
# Cost function =  4475613047016028.0
# Iteration = 97600
# Cost function =  4475603591879557.0
# Iteration = 97700
# Cost function =  4475594136782813.0
# Iteration = 97800
# Cost function =  4475584681725785.0
# Iteration = 97900
# Cost function =  4475575226708472.0
# Iteration = 98000
# Cost function =  4475565771730875.0
# Iteration = 98100
# Cost function =  4475556316793004.0
# Iteration = 98200
# Cost function =  4475546861894836.5
# Iteration = 98300
# Cost function =  4475537407036396.0
# Iteration = 98400
# Cost function =  4475527952217670.5
# Iteration = 98500
# Cost function =  4475518497438659.0
# Iteration = 98600
# Cost function =  4475509042699362.0
# Iteration = 98700
# Cost function =  4475499587999780.0
# Iteration = 98800
# Cost function =  4475490133339924.0
# Iteration = 98900
# Cost function =  4475480678719783.5
# Iteration = 99000
# Cost function =  4475471224139344.0
# Iteration = 99100
# Cost function =  4475461769598631.0
# Iteration = 99200
# Cost function =  4475452315097632.0
# Iteration = 99300
# Cost function =  4475442860636348.0
# Iteration = 99400
# Cost function =  4475433406214775.5
# Iteration = 99500
# Cost function =  4475423951832918.5
# Iteration = 99600
# Cost function =  4475414497490773.0
# Iteration = 99700
# Cost function =  4475405043188354.5
# Iteration = 99800
# Cost function =  4475395588925637.5
# Iteration = 99900
# Cost function =  4475386134702646.0
# Iteration = 100000
# Cost function =  4475376680519356.0
# Done with gradient descent at iteration  100000
# Learned weights =  [973.37072029 124.38876884]

# %% [markdown]
# This code will plot the two learned models.  (The blue line is for the model with no regularization and the red line is for the one with high regularization.)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(simple_feature_matrix,output,'k.',
         simple_feature_matrix,predict_output(simple_feature_matrix, simple_weights_0_penalty),'b-',
        simple_feature_matrix,predict_output(simple_feature_matrix, simple_weights_high_penalty),'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x22495e94160>,
#  <matplotlib.lines.Line2D at 0x22495e942e8>,
#  <matplotlib.lines.Line2D at 0x22495e94b38>,
#  <matplotlib.lines.Line2D at 0x22495e94cc0>,
#  <matplotlib.lines.Line2D at 0x22495e9c438>,
#  <matplotlib.lines.Line2D at 0x22495e9c5c0>]

# %% [markdown]
# Compute the RSS on the TEST data for the following three sets of weights:
# 1. The initial weights (all zeros)
# 2. The weights learned with no regularization
# 3. The weights learned with high regularization
#
# Which weights perform best?

# %%
np.sum((predict_output(get_numpy_data(test_data, simple_features, my_output)[0], simple_weights_high_penalty)\
        -get_numpy_data(test_data, simple_features, my_output)[1])**2)
# Out:
# 694653090427464.8

# %%
694653090427464.8<8e14
# Out:
# True

# %% [markdown]
# ***QUIZ QUESTIONS***
# 1. What is the value of the coefficient for `sqft_living` that you learned with no regularization, rounded to 1 decimal place?  What about the one with high regularization?
# 2. Comparing the lines you fit with the with no regularization versus high regularization, which one is steeper?
# 3. What are the RSS on the test data for each of the set of weights above (initial, no regularization, high regularization)?

# %% [markdown]
# # Running a multiple regression with L2 penalty

# %% [markdown]
# Let us now consider a model with 2 features: `['sqft_living', 'sqft_living15']`.

# %% [markdown]
# First, create Numpy versions of your training and test data with these two features.

# %%
np.sum((predict_output(get_numpy_data(test_data, model_features, my_output)[0], multiple_weights_0_penalty)\
        -get_numpy_data(test_data, model_features, my_output)[1])**2)
# Out:
# 274067615918575.53

# %%
model_features = ['sqft_living', 'sqft_living15'] # sqft_living15 is the average squarefeet for the nearest 15 neighbors. 
my_output = 'price'
(feature_matrix, output) = get_numpy_data(train_data, model_features, my_output)
(test_feature_matrix, test_output) = get_numpy_data(test_data, model_features, my_output)

# %% [markdown]
# We need to re-inialize the weights, since we have one extra parameter. Let us also set the step size and maximum number of iterations.

# %%
initial_weights = np.array([0.0,0.0,0.0])
step_size = 1e-12
max_iterations = 1000

# %% [markdown]
# First, let's consider no regularization.  Set the `l2_penalty` to `0.0` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `multiple_weights_0_penalty`

# %%
l2_penalty = 0.0
multiple_weights_0_penalty = ridge_regression_gradient_descent(feature_matrix, output, initial_weights, 
                                                             step_size, l2_penalty, max_iterations=1000)
# Out:
# Starting gradient descent with l2_penalty = 0.0
# Iteration = 1
# Cost function =  7433051852335772.0
# Iteration = 2
# Cost function =  4056752332045943.0
# Iteration = 3
# Cost function =  2529565114525309.0
# Iteration = 4
# Cost function =  1838556694300506.5
# Iteration = 5
# Cost function =  1525675575150296.5
# Iteration = 6
# Cost function =  1383789498571783.5
# Iteration = 7
# Cost function =  1319232606146273.8
# Iteration = 8
# Cost function =  1289648871879140.5
# Iteration = 9
# Cost function =  1275884723913737.0
# Iteration = 10
# Cost function =  1269278807397619.2
# Iteration = 20
# Cost function =  1257812386017016.5
# Iteration = 30
# Cost function =  1251954570861556.5
# Iteration = 40
# Cost function =  1246755422656426.0
# Iteration = 50
# Cost function =  1242139508166548.5
# Iteration = 60
# Cost function =  1238041400480994.0
# Iteration = 70
# Cost function =  1234403012742170.8
# Iteration = 80
# Cost function =  1231172774196731.5
# Iteration = 90
# Cost function =  1228304899227735.5
# Iteration = 100
# Cost function =  1225758738385979.0
# Iteration = 200
# Cost function =  1211738880290897.0
# Iteration = 300
# Cost function =  1207473079755049.8
# Iteration = 400
# Cost function =  1206175124539964.8
# Iteration = 500
# Cost function =  1205780188995876.5
# Iteration = 600
# Cost function =  1205660013231388.8
# Iteration = 700
# Cost function =  1205623438011734.0
# Iteration = 800
# Cost function =  1205612299743252.0
# Iteration = 900
# Cost function =  1205608901119130.8
# Iteration = 1000
# Cost function =  1205607857419329.8
# Done with gradient descent at iteration  1000
# Learned weights =  [ -0.35743483 243.05416982  22.41481497]

# %% [markdown]
# Next, let's consider high regularization.  Set the `l2_penalty` to `1e11` and run your ridge regression algorithm to learn the weights of your model.  Call your weights:
#
# `multiple_weights_high_penalty`

# %%
l2_penalty = 1e11
multiple_weights_high_penalty = ridge_regression_gradient_descent(feature_matrix, output, initial_weights, 
                                                             step_size, l2_penalty, max_iterations=1000)
# Out:
# Starting gradient descent with l2_penalty = 100000000000.0
# Iteration = 1
# Cost function =  7433051852335772.0
# Iteration = 2
# Cost function =  4460489790922031.0
# Iteration = 3
# Cost function =  3796674469325300.5
# Iteration = 4
# Cost function =  3648319530880128.0
# Iteration = 5
# Cost function =  3615091103648369.0
# Iteration = 6
# Cost function =  3607602742943372.5
# Iteration = 7
# Cost function =  3605886322588678.0
# Iteration = 8
# Cost function =  3605474874959446.0
# Iteration = 9
# Cost function =  3605365168191211.5
# Iteration = 10
# Cost function =  3605329402609966.0
# Iteration = 20
# Cost function =  3605294281447482.5
# Iteration = 30
# Cost function =  3605293537691883.0
# Iteration = 40
# Cost function =  3605293083174690.0
# Iteration = 50
# Cost function =  3605292631531144.0
# Iteration = 60
# Cost function =  3605292179916288.0
# Iteration = 70
# Cost function =  3605291728301859.0
# Iteration = 80
# Cost function =  3605291276687576.0
# Iteration = 90
# Cost function =  3605290825073434.5
# Iteration = 100
# Cost function =  3605290373459437.0
# Iteration = 200
# Cost function =  3605285857327309.5
# Iteration = 300
# Cost function =  3605281341209459.0
# Iteration = 400
# Cost function =  3605276825105885.0
# Iteration = 500
# Cost function =  3605272309016589.0
# Iteration = 600
# Cost function =  3605267792941569.5
# Iteration = 700
# Cost function =  3605263276880827.0
# Iteration = 800
# Cost function =  3605258760834361.0
# Iteration = 900
# Cost function =  3605254244802171.0
# Iteration = 1000
# Cost function =  3605249728784259.5
# Done with gradient descent at iteration  1000
# Learned weights =  [ 6.74296579 91.48927365 78.43658766]

# %% [markdown]
# Compute the RSS on the TEST data for the following three sets of weights:
# 1. The initial weights (all zeros)
# 2. The weights learned with no regularization
# 3. The weights learned with high regularization
#
# Which weights perform best?

# %% [markdown]
# Predict the house price for the 1st house in the test set using the no regularization and high regularization models. (Remember that python starts indexing from 0.) How far is the prediction from the actual price?  Which weights perform best for the 1st house?

# %%
multiple_weights_0_penalty
# Out:
# array([ -0.35743483, 243.05416982,  22.41481497])

# %% [markdown]
# ***QUIZ QUESTIONS***
# 1. What is the value of the coefficient for `sqft_living` that you learned with no regularization, rounded to 1 decimal place?  What about the one with high regularization?
# 2. What are the RSS on the test data for each of the set of weights above (initial, no regularization, high regularization)?
# 3. We make prediction for the first house in the test set using two sets of weights (no regularization vs high regularization). Which weights make better prediction <u>for that particular house</u>?
